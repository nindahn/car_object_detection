# %%
import numpy as np 
import pandas as pd
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image, ImageDraw, ImageEnhance
import albumentations as A
from tqdm.notebook import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Load training images filename and bounding boxes
dir_path = '/content/drive/MyDrive/Colab Notebooks/object_detection/data/'
train_bbox = pd.read_csv(dir_path + 'train_solution_bounding_boxes (1).csv')
train_bbox.head()
# Out:
#              image        xmin        ymin        xmax        ymax
# 0   vid_4_1000.jpg  281.259045  187.035071  327.727931  223.225547
# 1  vid_4_10000.jpg   15.163531  187.035071  120.329957  236.430180
# 2  vid_4_10040.jpg  239.192475  176.764801  361.968162  236.430180
# 3  vid_4_10020.jpg  496.483358  172.363256  630.020260  231.539575
# 4  vid_4_10060.jpg   16.630970  186.546010  132.558611  238.386422

# %%
# Show Images in train folder
train_folder_path = dir_path + 'training_images'
train_images = train_bbox['image']

nrows = 5
ncols = 5
pic_index = 0
fig = plt.gcf()
fig.set_size_inches(ncols * 5, nrows * 5)
pic_index += 10
train_img = [os.path.join(train_folder_path, fname) 
                for fname in train_images[pic_index-10:pic_index]]
for i, img_path in enumerate(train_img):
  sp = plt.subplot(nrows, ncols, i + 1)
  img = mpimg.imread(img_path)
  sp.set_xlabel('IMAGE SIZE {}x{}'.format(img.shape[0], img.shape[1]))
  sp.set_yticklabels([])
  sp.set_xticklabels([])
  plt.imshow(img)
plt.show()

# %%
#rescale bbox because we want to load and resize image to 256 x 256
train_bbox['xmin'] = train_bbox['xmin']/(676/256)
train_bbox['ymin'] = train_bbox['ymin']/(380/256)
train_bbox['xmax'] = train_bbox['xmax']/(676/256)
train_bbox['ymax'] = train_bbox['ymax']/(380/256)
train_bbox.head()
# Out:
#              image        xmin        ymin        xmax        ymax
# 0   vid_4_1000.jpg  106.512301  126.002574  124.109986  150.383526
# 1  vid_4_10000.jpg    5.742402  126.002574   45.568741  159.279279
# 2  vid_4_10040.jpg   90.581766  119.083655  137.076700  159.279279
# 3  vid_4_10020.jpg  188.017366  116.118404  238.587554  155.984556
# 4  vid_4_10060.jpg    6.298119  125.673102   50.199711  160.597169

# %%
#Load and show images with the bounding boxes
def load_image(image_path):
    image = Image.open(image_path)
    image = image.resize((256, 256))
    return np.asarray(image)

def draw_bboxes(image_path, bboxes):  
    image = Image.open(image_path)
    image = image.resize((256, 256))
    draw = ImageDraw.Draw(image)
            
    for bbox in bboxes:
        xmin, ymin, xmax, ymax = bbox
        draw.rectangle([xmin, ymin, xmax, ymax], width=2, outline='red')
    
    return np.asarray(image)

# %%
#group bboxes of each image
def groupbox(labels):
  return labels.iloc[:, 1:].values.astype(float)

train_bbox = train_bbox.groupby('image').apply(groupbox)

# %%
num_train = round(len(train_bbox)*0.8)
train_files = np.unique(train_bbox.index.values)[0:num_train]
val_files = np.unique(train_bbox.index.values)[num_train:len(train_bbox)+1]

train_img, train_box = {}, {}
val_img, val_box = {}, {}

for image_id in tqdm(train_files):
  train_img[image_id] = load_image(os.path.join(train_folder_path, image_id))
  train_box[image_id] = train_bbox[image_id].copy()

for image_id in tqdm(val_files):
  val_img[image_id] = load_image(os.path.join(train_folder_path, image_id))
  val_box[image_id] = train_bbox[image_id].copy()
# Out:
#   0%|          | 0/284 [00:00<?, ?it/s]
#   0%|          | 0/71 [00:00<?, ?it/s]

# %%
im_bbox = []
for image_id in train_files[0:5]:
  im_bbox.append(draw_bboxes(os.path.join(train_folder_path, image_id), train_box[image_id]))

n_images = len(train_files[0:5])
fig, axes = plt.subplots(1, n_images, figsize=(n_images * 5, n_images * 5))
for i, image_bbox in enumerate(im_bbox):
  axes[i].imshow(image_bbox)

# %%
class DataGenerator(tf.keras.utils.Sequence):

    def __init__(self, image_ids, image_pixels, labels=None, batch_size=1, shuffle=False, augment=False):
        self.image_ids = image_ids
        self.image_pixels = image_pixels
        self.labels = labels
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.augment = augment
        self.on_epoch_end()
        
        self.image_grid = self.form_image_grid()
              
    def form_image_grid(self):    
        image_grid = np.zeros((32, 32, 4))

        # x, y, width, height
        cell = [0, 0, 256 / 32, 256 / 32] 

        for i in range(0, 32):
            for j in range(0, 32):
                image_grid[i,j] = cell

                cell[0] = cell[0] + cell[2]

            cell[0] = 0
            cell[1] = cell[1] + cell[3]

        return image_grid

# %%
def __len__(self):
    return int(np.floor(len(self.image_ids) / self.batch_size))


def on_epoch_end(self):
    self.indexes = np.arange(len(self.image_ids))

    if self.shuffle == True:
        np.random.shuffle(self.indexes)


DataGenerator.__len__ = __len__
DataGenerator.on_epoch_end = on_epoch_end

# %%
#image augmentation using albumentations
DataGenerator.train_augmentations = A.Compose([
        A.RandomCrop( 
            height=256, 
            width=256, 
            p=0.8
        ),
        A.HorizontalFlip(p=0.5),
        A.OneOf([
            A.HueSaturationValue(),
            A.RandomBrightnessContrast()
        ], p=1),
        A.OneOf([
            A.GaussNoise()
        ], p=0.5),
    ], 
    bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

DataGenerator.val_augmentations = A.Compose([
    A.CLAHE(p=1),
    A.ToGray(p=1),
])

# %%
def __getitem__(self, index):
    indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]

    batch_ids = [self.image_ids[i] for i in indexes]

    X, y = self.__data_generation(batch_ids)

    return X, y


def __data_generation(self, batch_ids):
    X, y = [], []

    # Generate data
    for i, image_id in enumerate(batch_ids):
        pixels = self.image_pixels[image_id]
        bboxes = self.labels[image_id]

        if self.augment:     
            pixels, bboxes = self.augment_image(pixels, bboxes)
        else:
            pixels = self.contrast_image(pixels)
            bboxes = self.form_label_grid(bboxes)

        X.append(pixels)
        y.append(bboxes)

    return np.array(X), np.array(y)


def augment_image(self, pixels, bboxes):
    bbox_labels = np.ones(len(bboxes))

    aug_result = self.train_augmentations(image=pixels, bboxes=bboxes, labels=bbox_labels)

    bboxes = self.form_label_grid(aug_result['bboxes'])

    return np.array(aug_result['image']) / 255, bboxes


def contrast_image(self, pixels):        
    aug_result = self.val_augmentations(image=pixels)
    return np.array(aug_result['image']) / 255


DataGenerator.__getitem__ = __getitem__
DataGenerator.__data_generation = __data_generation
DataGenerator.augment_image = augment_image
DataGenerator.contrast_image = contrast_image

# %%
def form_label_grid(self, bboxes):
    label_grid = np.zeros((32, 32, 10))

    for i in range(0, 32):
        for j in range(0, 32):
            cell = self.image_grid[i,j]
            label_grid[i,j] = self.rect_intersect(cell, bboxes)

    return label_grid


def rect_intersect(self, cell, bboxes): 
    cell_x, cell_y, cell_width, cell_height = cell
    cell_x_max = cell_x + cell_width 
    cell_y_max = cell_y + cell_height
    
    anchor_one = np.array([0, 0, 0, 0, 0])
    anchor_two = np.array([0, 0, 0, 0, 0])

    # check all boxes
    for bbox in bboxes:
        box_x, box_y, box_width, box_height = bbox
        box_x_centre = box_x + (box_width / 2)
        box_y_centre = box_y + (box_height / 2)

        if(box_x_centre >= cell_x and box_x_centre < cell_x_max and box_y_centre >= cell_y and box_y_centre < cell_y_max):
            
            if anchor_one[0] == 0:
                anchor_one = self.yolo_shape(
                    [box_x, box_y, box_width, box_height], 
                    [cell_x, cell_y, cell_width, cell_height]
                )
            
            elif anchor_two[0] == 0:
                anchor_two = self.yolo_shape(
                    [box_x, box_y, box_width, box_height], 
                    [cell_x, cell_y, cell_width, cell_height]
                )
                
            else:
                break

    return np.concatenate((anchor_one, anchor_two), axis=None)


def yolo_shape(self, box, cell):
    box_x, box_y, box_width, box_height = box
    cell_x, cell_y, cell_width, cell_height = cell

    # top left x,y to centre x,y
    box_x = box_x + (box_width / 2)
    box_y = box_y + (box_height / 2)

    # offset bbox x,y to cell x,y
    box_x = (box_x - cell_x) / cell_width
    box_y = (box_y - cell_y) / cell_height

    # bbox width,height relative to cell width,height
    box_width = box_width / 256
    box_height = box_height / 256

    return [1, box_x, box_y, box_width, box_height]


DataGenerator.form_label_grid = form_label_grid
DataGenerator.rect_intersect = rect_intersect
DataGenerator.yolo_shape = yolo_shape

# %%
train_generator = DataGenerator(
    train_files,
    train_img,
    train_box, 
    batch_size=5, 
    shuffle=True,
    augment=True
)


val_generator = DataGenerator(
    val_files, 
    val_img,
    val_box, 
    batch_size=8,
    shuffle=False,
    augment=False
)

image_grid = train_generator.image_grid

# %%
x_input = tf.keras.Input(shape=(256,256,3))

x = tf.keras.layers.Conv2D(32, (3, 3), strides=(1, 1), padding='same')(x_input)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

########## block 1 ##########
x = tf.keras.layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x_shortcut = x

for i in range(2):
    x = tf.keras.layers.Conv2D(32, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Add()([x_shortcut, x])
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x_shortcut = x


########## block 2 ##########
x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x_shortcut = x

for i in range(2):
    x = tf.keras.layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Add()([x_shortcut, x])
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x_shortcut = x

########## block 3 ##########
x = tf.keras.layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x_shortcut = x

for i in range(8):
    x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Add()([x_shortcut, x])
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x_shortcut = x

    
########## block 4 ##########
x = tf.keras.layers.Conv2D(512, (3, 3), strides=(2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x_shortcut = x

for i in range(8):
    x = tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Add()([x_shortcut, x])
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x_shortcut = x

########## block 5 ##########
x = tf.keras.layers.Conv2D(1024, (3, 3), strides=(2, 2), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x_shortcut = x

for i in range(4):
    x = tf.keras.layers.Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Conv2D(1024, (3, 3), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x = tf.keras.layers.Add()([x_shortcut, x])
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    x_shortcut = x

########## output layers ##########
x = tf.keras.layers.Conv2D(512, (3, 3), strides=(1, 1), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x = tf.keras.layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

x = tf.keras.layers.Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

predictions = tf.keras.layers.Conv2D(10, (1, 1), strides=(1, 1), activation='sigmoid')(x)

model = tf.keras.Model(inputs=x_input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  leaky_re_lu (LeakyReLU)        (None, 256, 256, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  18496       ['leaky_re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 256, 256, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 32  18464       ['leaky_re_lu_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 256, 256, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 64  18496       ['leaky_re_lu_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 256, 256, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 256, 256, 64  0           ['leaky_re_lu_1[0][0]',
#                                 )                                 'leaky_re_lu_3[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 256, 256, 64  0           ['add[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 32  18464       ['leaky_re_lu_4[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 256, 256, 32  128        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 256, 256, 32  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 64  18496       ['leaky_re_lu_5[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 256, 256, 64  256        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 256, 256, 64  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 256, 256, 64  0           ['leaky_re_lu_4[0][0]',
#                                 )                                 'leaky_re_lu_6[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 256, 256, 64  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 12  73856       ['leaky_re_lu_7[0][0]']
#                                 8)
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 12  512        ['conv2d_6[0][0]']
#  rmalization)                   8)
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 256, 256, 12  0           ['batch_normalization_6[0][0]']
#                                 8)
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 64  73792       ['leaky_re_lu_8[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 256, 256, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 12  73856       ['leaky_re_lu_9[0][0]']
#                                 8)
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 12  512        ['conv2d_8[0][0]']
#  rmalization)                   8)
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 256, 256, 12  0           ['batch_normalization_8[0][0]']
#                                 8)
#
#  add_2 (Add)                    (None, 256, 256, 12  0           ['leaky_re_lu_8[0][0]',
#                                 8)                                'leaky_re_lu_10[0][0]']
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 256, 256, 12  0           ['add_2[0][0]']
#                                 8)
#
#  conv2d_9 (Conv2D)              (None, 256, 256, 64  73792       ['leaky_re_lu_11[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 256, 256, 64  256        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 256, 256, 64  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 256, 256, 12  73856       ['leaky_re_lu_12[0][0]']
#                                 8)
#
#  batch_normalization_10 (BatchN  (None, 256, 256, 12  512        ['conv2d_10[0][0]']
#  ormalization)                  8)
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 256, 256, 12  0           ['batch_normalization_10[0][0]']
#                                 8)
#
#  add_3 (Add)                    (None, 256, 256, 12  0           ['leaky_re_lu_11[0][0]',
#                                 8)                                'leaky_re_lu_13[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 256, 256, 12  0           ['add_3[0][0]']
#                                 8)
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 25  295168      ['leaky_re_lu_14[0][0]']
#                                 6)
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 25  1024       ['conv2d_11[0][0]']
#  ormalization)                  6)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 128, 128, 25  0           ['batch_normalization_11[0][0]']
#                                 6)
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 12  295040      ['leaky_re_lu_15[0][0]']
#                                 8)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 12  512        ['conv2d_12[0][0]']
#  ormalization)                  8)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 128, 128, 12  0           ['batch_normalization_12[0][0]']
#                                 8)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  295168      ['leaky_re_lu_16[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  add_4 (Add)                    (None, 128, 128, 25  0           ['leaky_re_lu_15[0][0]',
#                                 6)                                'leaky_re_lu_17[0][0]']
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 128, 128, 25  0           ['add_4[0][0]']
#                                 6)
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 12  295040      ['leaky_re_lu_18[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 128, 128, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 25  295168      ['leaky_re_lu_19[0][0]']
#                                 6)
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 25  1024       ['conv2d_15[0][0]']
#  ormalization)                  6)
#
#  leaky_re_lu_20 (LeakyReLU)     (None, 128, 128, 25  0           ['batch_normalization_15[0][0]']
#                                 6)
#
#  add_5 (Add)                    (None, 128, 128, 25  0           ['leaky_re_lu_18[0][0]',
#                                 6)                                'leaky_re_lu_20[0][0]']
#
#  leaky_re_lu_21 (LeakyReLU)     (None, 128, 128, 25  0           ['add_5[0][0]']
#                                 6)
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 12  295040      ['leaky_re_lu_21[0][0]']
#                                 8)
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 12  512        ['conv2d_16[0][0]']
#  ormalization)                  8)
#
#  leaky_re_lu_22 (LeakyReLU)     (None, 128, 128, 12  0           ['batch_normalization_16[0][0]']
#                                 8)
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 25  295168      ['leaky_re_lu_22[0][0]']
#                                 6)
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 25  1024       ['conv2d_17[0][0]']
#  ormalization)                  6)
#
#  leaky_re_lu_23 (LeakyReLU)     (None, 128, 128, 25  0           ['batch_normalization_17[0][0]']
#                                 6)
#
#  add_6 (Add)                    (None, 128, 128, 25  0           ['leaky_re_lu_21[0][0]',
#                                 6)                                'leaky_re_lu_23[0][0]']
#
#  leaky_re_lu_24 (LeakyReLU)     (None, 128, 128, 25  0           ['add_6[0][0]']
#                                 6)
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 12  295040      ['leaky_re_lu_24[0][0]']
#                                 8)
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 12  512        ['conv2d_18[0][0]']
#  ormalization)                  8)
#
#  leaky_re_lu_25 (LeakyReLU)     (None, 128, 128, 12  0           ['batch_normalization_18[0][0]']
#                                 8)
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 25  295168      ['leaky_re_lu_25[0][0]']
#                                 6)
#
#  batch_normalization_19 (BatchN  (None, 128, 128, 25  1024       ['conv2d_19[0][0]']
#  ormalization)                  6)
#
#  leaky_re_lu_26 (LeakyReLU)     (None, 128, 128, 25  0           ['batch_normalization_19[0][0]']
#                                 6)
#
#  add_7 (Add)                    (None, 128, 128, 25  0           ['leaky_re_lu_24[0][0]',
#                                 6)                                'leaky_re_lu_26[0][0]']
#
#  leaky_re_lu_27 (LeakyReLU)     (None, 128, 128, 25  0           ['add_7[0][0]']
#                                 6)
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 12  295040      ['leaky_re_lu_27[0][0]']
#                                 8)
#
#  batch_normalization_20 (BatchN  (None, 128, 128, 12  512        ['conv2d_20[0][0]']
#  ormalization)                  8)
#
#  leaky_re_lu_28 (LeakyReLU)     (None, 128, 128, 12  0           ['batch_normalization_20[0][0]']
#                                 8)
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 25  295168      ['leaky_re_lu_28[0][0]']
#                                 6)
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 25  1024       ['conv2d_21[0][0]']
#  ormalization)                  6)
#
#  leaky_re_lu_29 (LeakyReLU)     (None, 128, 128, 25  0           ['batch_normalization_21[0][0]']
#                                 6)
#
#  add_8 (Add)                    (None, 128, 128, 25  0           ['leaky_re_lu_27[0][0]',
#                                 6)                                'leaky_re_lu_29[0][0]']
#
#  leaky_re_lu_30 (LeakyReLU)     (None, 128, 128, 25  0           ['add_8[0][0]']
#                                 6)
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 12  295040      ['leaky_re_lu_30[0][0]']
#                                 8)
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 12  512        ['conv2d_22[0][0]']
#  ormalization)                  8)
#
#  leaky_re_lu_31 (LeakyReLU)     (None, 128, 128, 12  0           ['batch_normalization_22[0][0]']
#                                 8)
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 25  295168      ['leaky_re_lu_31[0][0]']
#                                 6)
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 25  1024       ['conv2d_23[0][0]']
#  ormalization)                  6)
#
#  leaky_re_lu_32 (LeakyReLU)     (None, 128, 128, 25  0           ['batch_normalization_23[0][0]']
#                                 6)
#
#  add_9 (Add)                    (None, 128, 128, 25  0           ['leaky_re_lu_30[0][0]',
#                                 6)                                'leaky_re_lu_32[0][0]']
#
#  leaky_re_lu_33 (LeakyReLU)     (None, 128, 128, 25  0           ['add_9[0][0]']
#                                 6)
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 12  295040      ['leaky_re_lu_33[0][0]']
#                                 8)
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 12  512        ['conv2d_24[0][0]']
#  ormalization)                  8)
#
#  leaky_re_lu_34 (LeakyReLU)     (None, 128, 128, 12  0           ['batch_normalization_24[0][0]']
#                                 8)
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 25  295168      ['leaky_re_lu_34[0][0]']
#                                 6)
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 25  1024       ['conv2d_25[0][0]']
#  ormalization)                  6)
#
#  leaky_re_lu_35 (LeakyReLU)     (None, 128, 128, 25  0           ['batch_normalization_25[0][0]']
#                                 6)
#
#  add_10 (Add)                   (None, 128, 128, 25  0           ['leaky_re_lu_33[0][0]',
#                                 6)                                'leaky_re_lu_35[0][0]']
#
#  leaky_re_lu_36 (LeakyReLU)     (None, 128, 128, 25  0           ['add_10[0][0]']
#                                 6)
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 12  295040      ['leaky_re_lu_36[0][0]']
#                                 8)
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 12  512        ['conv2d_26[0][0]']
#  ormalization)                  8)
#
#  leaky_re_lu_37 (LeakyReLU)     (None, 128, 128, 12  0           ['batch_normalization_26[0][0]']
#                                 8)
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 25  295168      ['leaky_re_lu_37[0][0]']
#                                 6)
#
#  batch_normalization_27 (BatchN  (None, 128, 128, 25  1024       ['conv2d_27[0][0]']
#  ormalization)                  6)
#
#  leaky_re_lu_38 (LeakyReLU)     (None, 128, 128, 25  0           ['batch_normalization_27[0][0]']
#                                 6)
#
#  add_11 (Add)                   (None, 128, 128, 25  0           ['leaky_re_lu_36[0][0]',
#                                 6)                                'leaky_re_lu_38[0][0]']
#
#  leaky_re_lu_39 (LeakyReLU)     (None, 128, 128, 25  0           ['add_11[0][0]']
#                                 6)
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 512)  1180160     ['leaky_re_lu_39[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_28[0][0]']
#  ormalization)
#
#  leaky_re_lu_40 (LeakyReLU)     (None, 64, 64, 512)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 256)  1179904     ['leaky_re_lu_40[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  leaky_re_lu_41 (LeakyReLU)     (None, 64, 64, 256)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 512)  1180160     ['leaky_re_lu_41[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  leaky_re_lu_42 (LeakyReLU)     (None, 64, 64, 512)  0           ['batch_normalization_30[0][0]']
#
#  add_12 (Add)                   (None, 64, 64, 512)  0           ['leaky_re_lu_40[0][0]',
#                                                                   'leaky_re_lu_42[0][0]']
#
#  leaky_re_lu_43 (LeakyReLU)     (None, 64, 64, 512)  0           ['add_12[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 256)  1179904     ['leaky_re_lu_43[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  leaky_re_lu_44 (LeakyReLU)     (None, 64, 64, 256)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 512)  1180160     ['leaky_re_lu_44[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_32[0][0]']
#  ormalization)
#
#  leaky_re_lu_45 (LeakyReLU)     (None, 64, 64, 512)  0           ['batch_normalization_32[0][0]']
#
#  add_13 (Add)                   (None, 64, 64, 512)  0           ['leaky_re_lu_43[0][0]',
#                                                                   'leaky_re_lu_45[0][0]']
#
#  leaky_re_lu_46 (LeakyReLU)     (None, 64, 64, 512)  0           ['add_13[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 256)  1179904     ['leaky_re_lu_46[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  leaky_re_lu_47 (LeakyReLU)     (None, 64, 64, 256)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 512)  1180160     ['leaky_re_lu_47[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_34[0][0]']
#  ormalization)
#
#  leaky_re_lu_48 (LeakyReLU)     (None, 64, 64, 512)  0           ['batch_normalization_34[0][0]']
#
#  add_14 (Add)                   (None, 64, 64, 512)  0           ['leaky_re_lu_46[0][0]',
#                                                                   'leaky_re_lu_48[0][0]']
#
#  leaky_re_lu_49 (LeakyReLU)     (None, 64, 64, 512)  0           ['add_14[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 64, 64, 256)  1179904     ['leaky_re_lu_49[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_35[0][0]']
#  ormalization)
#
#  leaky_re_lu_50 (LeakyReLU)     (None, 64, 64, 256)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 64, 64, 512)  1180160     ['leaky_re_lu_50[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_36[0][0]']
#  ormalization)
#
#  leaky_re_lu_51 (LeakyReLU)     (None, 64, 64, 512)  0           ['batch_normalization_36[0][0]']
#
#  add_15 (Add)                   (None, 64, 64, 512)  0           ['leaky_re_lu_49[0][0]',
#                                                                   'leaky_re_lu_51[0][0]']
#
#  leaky_re_lu_52 (LeakyReLU)     (None, 64, 64, 512)  0           ['add_15[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 64, 64, 256)  1179904     ['leaky_re_lu_52[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_37[0][0]']
#  ormalization)
#
#  leaky_re_lu_53 (LeakyReLU)     (None, 64, 64, 256)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 512)  1180160     ['leaky_re_lu_53[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_38[0][0]']
#  ormalization)
#
#  leaky_re_lu_54 (LeakyReLU)     (None, 64, 64, 512)  0           ['batch_normalization_38[0][0]']
#
#  add_16 (Add)                   (None, 64, 64, 512)  0           ['leaky_re_lu_52[0][0]',
#                                                                   'leaky_re_lu_54[0][0]']
#
#  leaky_re_lu_55 (LeakyReLU)     (None, 64, 64, 512)  0           ['add_16[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 64, 64, 256)  1179904     ['leaky_re_lu_55[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_39[0][0]']
#  ormalization)
#
#  leaky_re_lu_56 (LeakyReLU)     (None, 64, 64, 256)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 64, 64, 512)  1180160     ['leaky_re_lu_56[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_40[0][0]']
#  ormalization)
#
#  leaky_re_lu_57 (LeakyReLU)     (None, 64, 64, 512)  0           ['batch_normalization_40[0][0]']
#
#  add_17 (Add)                   (None, 64, 64, 512)  0           ['leaky_re_lu_55[0][0]',
#                                                                   'leaky_re_lu_57[0][0]']
#
#  leaky_re_lu_58 (LeakyReLU)     (None, 64, 64, 512)  0           ['add_17[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 256)  1179904     ['leaky_re_lu_58[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_41[0][0]']
#  ormalization)
#
#  leaky_re_lu_59 (LeakyReLU)     (None, 64, 64, 256)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 64, 64, 512)  1180160     ['leaky_re_lu_59[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_42[0][0]']
#  ormalization)
#
#  leaky_re_lu_60 (LeakyReLU)     (None, 64, 64, 512)  0           ['batch_normalization_42[0][0]']
#
#  add_18 (Add)                   (None, 64, 64, 512)  0           ['leaky_re_lu_58[0][0]',
#                                                                   'leaky_re_lu_60[0][0]']
#
#  leaky_re_lu_61 (LeakyReLU)     (None, 64, 64, 512)  0           ['add_18[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 64, 64, 256)  1179904     ['leaky_re_lu_61[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_43[0][0]']
#  ormalization)
#
#  leaky_re_lu_62 (LeakyReLU)     (None, 64, 64, 256)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 64, 64, 512)  1180160     ['leaky_re_lu_62[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_44[0][0]']
#  ormalization)
#
#  leaky_re_lu_63 (LeakyReLU)     (None, 64, 64, 512)  0           ['batch_normalization_44[0][0]']
#
#  add_19 (Add)                   (None, 64, 64, 512)  0           ['leaky_re_lu_61[0][0]',
#                                                                   'leaky_re_lu_63[0][0]']
#
#  leaky_re_lu_64 (LeakyReLU)     (None, 64, 64, 512)  0           ['add_19[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 1024  4719616     ['leaky_re_lu_64[0][0]']
#                                 )
#
#  batch_normalization_45 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_45[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_65 (LeakyReLU)     (None, 32, 32, 1024  0           ['batch_normalization_45[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 512)  4719104     ['leaky_re_lu_65[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_46[0][0]']
#  ormalization)
#
#  leaky_re_lu_66 (LeakyReLU)     (None, 32, 32, 512)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 1024  4719616     ['leaky_re_lu_66[0][0]']
#                                 )
#
#  batch_normalization_47 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_47[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_67 (LeakyReLU)     (None, 32, 32, 1024  0           ['batch_normalization_47[0][0]']
#                                 )
#
#  add_20 (Add)                   (None, 32, 32, 1024  0           ['leaky_re_lu_65[0][0]',
#                                 )                                 'leaky_re_lu_67[0][0]']
#
#  leaky_re_lu_68 (LeakyReLU)     (None, 32, 32, 1024  0           ['add_20[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 512)  4719104     ['leaky_re_lu_68[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_48[0][0]']
#  ormalization)
#
#  leaky_re_lu_69 (LeakyReLU)     (None, 32, 32, 512)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 1024  4719616     ['leaky_re_lu_69[0][0]']
#                                 )
#
#  batch_normalization_49 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_49[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_70 (LeakyReLU)     (None, 32, 32, 1024  0           ['batch_normalization_49[0][0]']
#                                 )
#
#  add_21 (Add)                   (None, 32, 32, 1024  0           ['leaky_re_lu_68[0][0]',
#                                 )                                 'leaky_re_lu_70[0][0]']
#
#  leaky_re_lu_71 (LeakyReLU)     (None, 32, 32, 1024  0           ['add_21[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 512)  4719104     ['leaky_re_lu_71[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_50[0][0]']
#  ormalization)
#
#  leaky_re_lu_72 (LeakyReLU)     (None, 32, 32, 512)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 32, 32, 1024  4719616     ['leaky_re_lu_72[0][0]']
#                                 )
#
#  batch_normalization_51 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_51[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_73 (LeakyReLU)     (None, 32, 32, 1024  0           ['batch_normalization_51[0][0]']
#                                 )
#
#  add_22 (Add)                   (None, 32, 32, 1024  0           ['leaky_re_lu_71[0][0]',
#                                 )                                 'leaky_re_lu_73[0][0]']
#
#  leaky_re_lu_74 (LeakyReLU)     (None, 32, 32, 1024  0           ['add_22[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 32, 32, 512)  4719104     ['leaky_re_lu_74[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_52[0][0]']
#  ormalization)
#
#  leaky_re_lu_75 (LeakyReLU)     (None, 32, 32, 512)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 32, 32, 1024  4719616     ['leaky_re_lu_75[0][0]']
#                                 )
#
#  batch_normalization_53 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_53[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_76 (LeakyReLU)     (None, 32, 32, 1024  0           ['batch_normalization_53[0][0]']
#                                 )
#
#  add_23 (Add)                   (None, 32, 32, 1024  0           ['leaky_re_lu_74[0][0]',
#                                 )                                 'leaky_re_lu_76[0][0]']
#
#  leaky_re_lu_77 (LeakyReLU)     (None, 32, 32, 1024  0           ['add_23[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 32, 32, 512)  4719104     ['leaky_re_lu_77[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_54[0][0]']
#  ormalization)
#
#  leaky_re_lu_78 (LeakyReLU)     (None, 32, 32, 512)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 32, 32, 256)  1179904     ['leaky_re_lu_78[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_55[0][0]']
#  ormalization)
#
#  leaky_re_lu_79 (LeakyReLU)     (None, 32, 32, 256)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 32, 32, 128)  295040      ['leaky_re_lu_79[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 32, 32, 128)  512        ['conv2d_56[0][0]']
#  ormalization)
#
#  leaky_re_lu_80 (LeakyReLU)     (None, 32, 32, 128)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 32, 32, 10)   1290        ['leaky_re_lu_80[0][0]']
#
# ==================================================================================================
# Total params: 74,285,194
# Trainable params: 74,247,498
# Non-trainable params: 37,696
# __________________________________________________________________________________________________

# %%
def custom_loss(y_true, y_pred):
    binary_crossentropy = prob_loss = tf.keras.losses.BinaryCrossentropy(
        reduction=tf.keras.losses.Reduction.SUM_OVER_BATCH_SIZE
    )
    
    prob_loss = binary_crossentropy(
        tf.concat([y_true[:,:,:,0], y_true[:,:,:,5]], axis=0), 
        tf.concat([y_pred[:,:,:,0], y_pred[:,:,:,5]], axis=0)
    )
    
    xy_loss = tf.keras.losses.MSE(
        tf.concat([y_true[:,:,:,1:3], y_true[:,:,:,6:8]], axis=0), 
        tf.concat([y_pred[:,:,:,1:3], y_pred[:,:,:,6:8]], axis=0)
    )
    
    wh_loss = tf.keras.losses.MSE(
        tf.concat([y_true[:,:,:,3:5], y_true[:,:,:,8:10]], axis=0), 
        tf.concat([y_pred[:,:,:,3:5], y_pred[:,:,:,8:10]], axis=0)
    )
    
    bboxes_mask = get_mask(y_true)
    
    xy_loss = xy_loss * bboxes_mask
    wh_loss = wh_loss * bboxes_mask
    
    return prob_loss + xy_loss + wh_loss


def get_mask(y_true):
    anchor_one_mask = tf.where(
        y_true[:,:,:,0] == 0, 
        0.5, 
        5.0
    )
    
    anchor_two_mask = tf.where(
        y_true[:,:,:,5] == 0, 
        0.5, 
        5.0
    )
    
    bboxes_mask = tf.concat(
        [anchor_one_mask,anchor_two_mask],
        axis=0
    )
    
    return bboxes_mask

# %%
optimiser = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(
    optimizer=optimiser, 
    loss=custom_loss
)

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', patience=2, verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5, verbose=1, restore_best_weights=True),
]

# %%
history = model.fit_generator(
    train_generator,
    validation_data=val_generator,
    epochs=80,
    callbacks=callbacks
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
# Epoch 1/80
# 56/56 [==============================] - 127s 2s/step - loss: 0.4424 - val_loss: 1.0017 - lr: 1.0000e-04
# Epoch 2/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.2706 - val_loss: 1.0048 - lr: 1.0000e-04
# Epoch 3/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.2213 - val_loss: 0.2456 - lr: 1.0000e-04
# Epoch 4/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.1784 - val_loss: 0.1809 - lr: 1.0000e-04
# Epoch 5/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.1470 - val_loss: 0.1446 - lr: 1.0000e-04
# Epoch 6/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.1347 - val_loss: 0.1751 - lr: 1.0000e-04
# Epoch 7/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.1084 - val_loss: 0.1107 - lr: 1.0000e-04
# Epoch 8/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0909 - val_loss: 0.0871 - lr: 1.0000e-04
# Epoch 9/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0779 - val_loss: 0.0835 - lr: 1.0000e-04
# Epoch 10/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0675 - val_loss: 0.0676 - lr: 1.0000e-04
# Epoch 11/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0595 - val_loss: 0.0615 - lr: 1.0000e-04
# Epoch 12/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0523 - val_loss: 0.0504 - lr: 1.0000e-04
# Epoch 13/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0463 - val_loss: 0.0451 - lr: 1.0000e-04
# Epoch 14/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0411 - val_loss: 0.0403 - lr: 1.0000e-04
# Epoch 15/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0372 - val_loss: 0.0346 - lr: 1.0000e-04
# Epoch 16/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0337 - val_loss: 0.0318 - lr: 1.0000e-04
# Epoch 17/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0303 - val_loss: 0.0299 - lr: 1.0000e-04
# Epoch 18/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0279 - val_loss: 0.0270 - lr: 1.0000e-04
# Epoch 19/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0256 - val_loss: 0.0241 - lr: 1.0000e-04
# Epoch 20/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0237 - val_loss: 0.0214 - lr: 1.0000e-04
# Epoch 21/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0218 - val_loss: 0.0210 - lr: 1.0000e-04
# Epoch 22/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0202 - val_loss: 0.0192 - lr: 1.0000e-04
# Epoch 23/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0189 - val_loss: 0.0183 - lr: 1.0000e-04
# Epoch 24/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0177 - val_loss: 0.0171 - lr: 1.0000e-04
# Epoch 25/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0167 - val_loss: 0.0171 - lr: 1.0000e-04
# Epoch 26/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0156 - val_loss: 0.0166 - lr: 1.0000e-04
# Epoch 27/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0150 - val_loss: 0.0148 - lr: 1.0000e-04
# Epoch 28/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0142 - val_loss: 0.0140 - lr: 1.0000e-04
# Epoch 29/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0134 - val_loss: 0.0132 - lr: 1.0000e-04
# Epoch 30/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0128 - val_loss: 0.0130 - lr: 1.0000e-04
# Epoch 31/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0123 - val_loss: 0.0122 - lr: 1.0000e-04
# Epoch 32/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0116 - val_loss: 0.0117 - lr: 1.0000e-04
# Epoch 33/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0113 - val_loss: 0.0119 - lr: 1.0000e-04
# Epoch 34/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0109 - val_loss: 0.0108 - lr: 1.0000e-04
# Epoch 35/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0105 - val_loss: 0.0106 - lr: 1.0000e-04
# Epoch 36/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0101 - val_loss: 0.0110 - lr: 1.0000e-04
# Epoch 37/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0097 - val_loss: 0.0099 - lr: 1.0000e-04
# Epoch 38/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0093 - val_loss: 0.0091 - lr: 1.0000e-04
# Epoch 39/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0090 - val_loss: 0.0090 - lr: 1.0000e-04
# Epoch 40/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0088 - val_loss: 0.0090 - lr: 1.0000e-04
# Epoch 41/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0085 - val_loss: 0.0085 - lr: 1.0000e-04
# Epoch 42/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0083 - val_loss: 0.0079 - lr: 1.0000e-04
# Epoch 43/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0080 - val_loss: 0.0086 - lr: 1.0000e-04
# Epoch 44/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0076 - val_loss: 0.0087 - lr: 1.0000e-04
# Epoch 45/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0073 - val_loss: 0.0077 - lr: 1.0000e-04
# Epoch 46/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0073 - val_loss: 0.0089 - lr: 1.0000e-04
# Epoch 47/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0070 - val_loss: 0.0080 - lr: 1.0000e-04
# Epoch 48/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0067 - val_loss: 0.0072 - lr: 1.0000e-04
# Epoch 49/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0066 - val_loss: 0.0072 - lr: 1.0000e-04
# Epoch 50/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0065 - val_loss: 0.0068 - lr: 1.0000e-04
# Epoch 51/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0061 - val_loss: 0.0067 - lr: 1.0000e-04
# Epoch 52/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0061 - val_loss: 0.0064 - lr: 1.0000e-04
# Epoch 53/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0057 - val_loss: 0.0065 - lr: 1.0000e-04
# Epoch 54/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0055 - val_loss: 0.0064 - lr: 1.0000e-04
# Epoch 55/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0061 - val_loss: 0.0063 - lr: 1.0000e-04
# Epoch 56/80
# 56/56 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 56: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 56/56 [==============================] - 97s 2s/step - loss: 0.0054 - val_loss: 0.0059 - lr: 1.0000e-04
# Epoch 57/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0051 - val_loss: 0.0054 - lr: 1.0000e-05
# Epoch 58/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0050 - val_loss: 0.0053 - lr: 1.0000e-05
# Epoch 59/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0049 - val_loss: 0.0053 - lr: 1.0000e-05
# Epoch 60/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0048 - val_loss: 0.0053 - lr: 1.0000e-05
# Epoch 61/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0049 - val_loss: 0.0053 - lr: 1.0000e-05
# Epoch 62/80
# 56/56 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 62: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 56/56 [==============================] - 98s 2s/step - loss: 0.0047 - val_loss: 0.0053 - lr: 1.0000e-05
# Epoch 63/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0047 - val_loss: 0.0051 - lr: 1.0000e-06
# Epoch 64/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0047 - val_loss: 0.0051 - lr: 1.0000e-06
# Epoch 65/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0046 - val_loss: 0.0052 - lr: 1.0000e-06
# Epoch 66/80
# 56/56 [==============================] - 97s 2s/step - loss: 0.0047 - val_loss: 0.0051 - lr: 1.0000e-06
# Epoch 67/80
# 56/56 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 67: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 56/56 [==============================] - 97s 2s/step - loss: 0.0047 - val_loss: 0.0051 - lr: 1.0000e-06
# Epoch 68/80
# 56/56 [==============================] - 98s 2s/step - loss: 0.0047 - val_loss: 0.0051 - lr: 1.0000e-07
# Epoch 69/80
# 56/56 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 56/56 [==============================] - 97s 2s/step - loss: 0.0047 - val_loss: 0.0051 - lr: 1.0000e-07
# Epoch 70/80
# 56/56 [==============================] - ETA: 0s - loss: 0.0046Restoring model weights from the end of the best epoch: 65.
# 56/56 [==============================] - 97s 2s/step - loss: 0.0046 - val_loss: 0.0051 - lr: 1.0000e-08
# Epoch 70: early stopping

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/model_od.h5')

# %%
model.load_weights('/content/drive/MyDrive/Colab Notebooks/model.h5')

# %%
def prediction_to_bbox(bboxes, image_grid):    
    bboxes = bboxes.copy()
    
    im_width = (image_grid[:,:,2] * 32)
    im_height = (image_grid[:,:,3] * 32)
    
    # descale x,y
    bboxes[:,:,1] = (bboxes[:,:,1] * image_grid[:,:,2]) + image_grid[:,:,0]
    bboxes[:,:,2] = (bboxes[:,:,2] * image_grid[:,:,3]) + image_grid[:,:,1]
    bboxes[:,:,6] = (bboxes[:,:,6] * image_grid[:,:,2]) + image_grid[:,:,0]
    bboxes[:,:,7] = (bboxes[:,:,7] * image_grid[:,:,3]) + image_grid[:,:,1]
    
    # descale width,height
    bboxes[:,:,3] = bboxes[:,:,3] * im_width 
    bboxes[:,:,4] = bboxes[:,:,4] * im_height
    bboxes[:,:,8] = bboxes[:,:,8] * im_width 
    bboxes[:,:,9] = bboxes[:,:,9] * im_height
    
    # centre x,y to top left x,y
    bboxes[:,:,1] = bboxes[:,:,1] - (bboxes[:,:,3] / 2)
    bboxes[:,:,2] = bboxes[:,:,2] - (bboxes[:,:,4] / 2)
    bboxes[:,:,6] = bboxes[:,:,6] - (bboxes[:,:,8] / 2)
    bboxes[:,:,7] = bboxes[:,:,7] - (bboxes[:,:,9] / 2)
    
    # width,heigth to x_max,y_max
    bboxes[:,:,3] = bboxes[:,:,1] + bboxes[:,:,3]
    bboxes[:,:,4] = bboxes[:,:,2] + bboxes[:,:,4]
    bboxes[:,:,8] = bboxes[:,:,6] + bboxes[:,:,8]
    bboxes[:,:,9] = bboxes[:,:,7] + bboxes[:,:,9]
    
    return bboxes

# %%
def non_max_suppression(predictions, top_n):
    probabilities = np.concatenate((predictions[:,:,0].flatten(), predictions[:,:,5].flatten()), axis=None)
    
    first_anchors = predictions[:,:,1:5].reshape((32*32, 4))
    second_anchors = predictions[:,:,6:10].reshape((32*32, 4))
    
    bboxes = np.concatenate(
        (first_anchors,second_anchors),
        axis=0
    )
    
    bboxes = switch_x_y(bboxes)
    bboxes, probabilities = select_top(probabilities, bboxes, top_n=top_n)
    bboxes = switch_x_y(bboxes)
    
    return bboxes


def switch_x_y(bboxes):
    x1 = bboxes[:,0].copy()
    y1 = bboxes[:,1].copy()
    x2 = bboxes[:,2].copy()
    y2 = bboxes[:,3].copy()
    
    bboxes[:,0] = y1
    bboxes[:,1] = x1
    bboxes[:,2] = y2
    bboxes[:,3] = x2
    
    return bboxes


def select_top(probabilities, boxes, top_n=10):
    top_indices = tf.image.non_max_suppression(
        boxes = boxes, 
        scores = probabilities, 
        max_output_size = top_n, 
        iou_threshold = 0.3,
        score_threshold = 0.3
    )
    
    top_indices = top_indices.numpy()
    
    return boxes[top_indices], probabilities[top_indices]

# %%
def process_predictions(predictions, image_ids, image_grid):
    bboxes = {}
    
    for i, image_id in enumerate(image_ids):
        predictions[i] = prediction_to_bbox(predictions[i], image_grid)
        bboxes[image_id] = non_max_suppression(predictions[i], top_n=100)
        
        bboxes[image_id][:,2:4] = bboxes[image_id][:,2:4] - bboxes[image_id][:,0:2]
    
    return bboxes

# %%
test_folder_path = '/content/drive/MyDrive/Colab Notebooks/object_detection/data/testing_images/'
test_image_ids = os.listdir(test_folder_path)
test_image_ids = [image_id[:-4] for image_id in test_image_ids]

# %%
test_predictions = []

for i, image_id in enumerate(test_image_ids):
    image = Image.open(os.path.join(test_folder_path, image_id + '.jpg'))
    image = image.resize((256, 256))            

    pixels = np.asarray(image)

    val_augmentations = A.Compose([
        A.CLAHE(p=1),
        A.ToGray(p=1)
    ])

    aug_result = val_augmentations(image=pixels)
    pixels = np.array(aug_result['image']) / 255
    
    pixels = np.expand_dims(pixels, axis=0)
    
    bboxes = model.predict(pixels)

    test_predictions.append(bboxes)
    
test_predictions = np.concatenate(test_predictions)

# %%
test_predictions = process_predictions(test_predictions, test_image_ids, image_grid)

# %%
im_bbox = []
for image_id in test_image_ids:
  im_bbox.append(draw_bboxes(os.path.join(test_folder_path, image_id + '.jpg'), test_predictions[image_id]))

# %%
n_images = len(test_image_ids[0:5])
fig, axes = plt.subplots(1, n_images, figsize=(n_images * 5, n_images * 5))
for i, image_bbox in enumerate(im_bbox[0:5]):
  axes[i].imshow(image_bbox)
